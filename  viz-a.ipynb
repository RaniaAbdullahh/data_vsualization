# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset('planets')

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
sns.relplot(x='year', y='distance',data=df)

# %%
sns.lmplot(x='year', y='distance',data=df)

# %%
# Out:
# <AxesSubplot:xlabel='year', ylabel='distance'>

# %% [markdown]
# ## conclousion

# %% [markdown]
# these dataset  toke from seaborn data which indecates some informations about Planets and its orbital periods,mass and the years
# and  the relation between the earth year and the distance between the earth and that planet.
