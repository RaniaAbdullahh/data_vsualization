# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
  df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip',data=df)

# %%
sns.lmplot(x='total_bill', y='tip',data=df)

# %%
sns.barplot(x='total_bill', y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Conclousion

# %% [markdown]
# these dataset  toke from seaborn data which indecates some informations about some resturants which indecatsthe  total bills, meals , jender of vesetors and the tips,
# and the graph above repesents the relation between the total bills and the tips which takes a linear behavior..
